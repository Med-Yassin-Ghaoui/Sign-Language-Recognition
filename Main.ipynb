# %%
print('golla')
# Out:
# golla

# %%
import tensorflow as tf

# %%
import tensorflow as tf
import numpy as np
import matplotlib as plt
import mediapipe as mp
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       2 import numpy as np
#       3 import matplotlib as plt
# ----> 4 import mediapipe as mp
#
# File c:\Users\MSI\Documents\AI Porjects\Sign Language Recognition\.venv310\lib\site-packages\mediapipe\__init__.py:20
#      16 import mediapipe.python.solutions as solutions
#      17 import mediapipe.tasks.python as tasks
# ---> 20 del framework
#      21 del gpu
#      22 del modules
#
# NameError: name 'framework' is not defined

# %%
import tensorflow as tf
print(tf.config.list_physical_devices("GPU"))
